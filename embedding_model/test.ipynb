# %%
import pandas as pd
path = "/ltstorage/shares/datasets/eu/category15/metadata_similarity_unique.csv"

# Auto-detect delimiter; safe for large files
df = pd.read_csv(path, sep=None, engine="python", nrows=5)
print(df.head())       # or just df
# print(df.dtypes)       # optional: see column types
# Out:
#                                            filepath1  \
# 0  /ltstorage/shares/datasets/eu/category15/json_...
# 1  /ltstorage/shares/datasets/eu/category15/json_...
# 2  /ltstorage/shares/datasets/eu/category15/json_...
# 3  /ltstorage/shares/datasets/eu/category15/json_...
# 4  /ltstorage/shares/datasets/eu/category15/json_...
#
#                                            filepath2  similarity_full  \
# 0  /ltstorage/shares/datasets/eu/category15/json_...           0.1495
# 1  /ltstorage/shares/datasets/eu/category15/json_...           0.1701
# 2  /ltstorage/shares/datasets/eu/category15/json_...           0.1533
# 3  /ltstorage/shares/datasets/eu/category15/json_...           0.1579
# 4  /ltstorage/shares/datasets/eu/category15/json_...           0.1741
#
#    similarity_skip5
# 0            0.1411
# 1            0.1683
# 2            0.1452
# 3            0.1571
# 4            0.1423

# %%
import pandas as pd
path = "/ltstorage/shares/datasets/eu/category15/metadata_results.csv"

# Auto-detect delimiter; safe for large files
df = pd.read_csv(path, sep=None, engine="python", nrows=5)
print(df.head())       # or just df
# print(df.dtypes)       # optional: see column types
# Out:
#                                             metadata  \
# 0  KOMISJONI OTSUS,\n23. mai 2007,\nmilles käsitl...
# 1  KOMISIJAS LĒMUMS\n(2007. gada 23. maijs)\npar ...
# 2  DECYZJA KOMISJI\nz dnia 23 maja 2007 r.\ndotyc...
# 3  A BIZOTTSÁG HATÁROZATA\n(2007. május 23.)\n\ne...
# 4  ROZHODNUTIE KOMISIE\nz 23. mája 2007,\nktorým ...
#
#                                             filepath
# 0  /ltstorage/shares/datasets/eu/category15/json_...
# 1  /ltstorage/shares/datasets/eu/category15/json_...
# 2  /ltstorage/shares/datasets/eu/category15/json_...
# 3  /ltstorage/shares/datasets/eu/category15/json_...
# 4  /ltstorage/shares/datasets/eu/category15/json_...
